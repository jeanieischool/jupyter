# %% [markdown]
# #### Library imports

# %%
#matplotlib.use('TkAgg')
# %matplotlib inline
# %pylab inline
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans

import matplotlib

import matplotlib.pyplot as plt
from scipy.spatial.distance import cdist, pdist
import random
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# import data
yelp_reviews = pd.read_csv('yelp_reviewers.txt',sep='|',header=0)
yelp_reviews = yelp_reviews.fillna(0)

# sample data
rows = yelp_reviews.sample(1000)

# %% [markdown]
# ### Plotting silhouette scores for clusters

# %%
from sklearn.metrics import silhouette_score

def plot_silhouette_scores(data_set):
    s=[]
    for n_clusters in range(2,8):
        kmeans = KMeans(n_clusters=n_clusters)
        kmeans.fit(data_set)
    
        labels = kmeans.labels_
        centroids = kmeans.cluster_centers_
    
        s.append(silhouette_score(data_set,labels,metric='euclidean'))
#         print(s)
    plt.plot(s)

# %% [markdown]
# ### Q2. Clusters for features: q4,q5,q6

# %%
X1 = rows[['q4','q5','q6']]
y = rows['user_id']

# %%
plot_silhouette_scores(X1)

# %% [markdown]
# ### Q3. Clusters for features: q8,q9,q10

# %%
X2 = rows[['q8','q9','q10']]
# replacing inf with 0
X2.replace('inf',0)
# Out:
#              q8        q9       q10
# 27737  0.000000  0.000000  0.000000
# 27507  0.000000  0.000000  0.000000
# 40526  0.000000  0.000000  0.000000
# 18675  0.693147  0.000000  2.197225
# 26643  2.484907  2.397895  2.708050
# 4703   0.000000  0.000000  0.000000
# 40409  0.000000  0.000000  0.000000
# 6904   0.000000  0.000000  0.000000
# 5343   0.000000  0.000000  0.000000
# 16483  0.693147  0.000000  1.386294
# 8491   0.693147  0.000000  0.000000
# 12469  0.000000  0.000000  0.693147
# 12925  0.000000  0.000000  1.098612
# 2171   0.000000  0.000000  0.000000
# 30240  2.397895  1.791759  2.397895
# 17622  0.000000  0.000000  0.000000
# 41886  0.000000  0.000000  0.000000
# 1177   0.000000  0.000000  0.000000
# 11193  0.000000  0.000000  0.000000
# 22348  0.000000  0.000000  0.693147
# 1074   0.000000  0.000000  0.000000
# 23649  0.000000  0.000000  0.000000
# 37134  0.000000  0.000000  0.000000
# 25781  1.609438  1.386294  2.890372
# 9030   0.000000  0.000000  0.693147
# 32108  0.000000  0.000000  0.000000
# 44230  0.000000  0.000000  0.000000
# 29135  0.000000  0.000000  0.000000
# 37750  0.000000  0.000000  0.000000
# 12000  0.000000  0.000000  0.000000
# ...         ...       ...       ...
# 11059  0.000000  0.000000  0.000000
# 33684  0.000000  0.000000  0.000000
# 35319  3.401197  3.737670  3.761200
# 8857   0.000000  0.000000  0.000000
# 25804  0.000000  0.000000  0.000000
# 5984   1.945910  2.302585  2.197225
# 13000  0.000000  0.000000  1.386294
# 31512  0.000000  0.000000  0.000000
# 10552  0.000000  0.693147  1.945910
# 31205  0.000000  0.000000  0.000000
# 33348  0.000000  0.000000  1.609438
# 15430  1.098612  0.000000  2.079442
# 27825  0.000000  0.000000  0.000000
# 16280  0.000000  0.000000  0.000000
# 10142  0.000000  0.000000  0.693147
# 1201   0.000000  0.000000  0.000000
# 35555  1.386294  1.609438  1.609438
# 25108  0.000000  0.000000  0.000000
# 43176  0.000000  0.000000  0.000000
# 13089  0.000000  0.000000  0.000000
# 22989  0.000000  0.000000  0.000000
# 31453  0.000000  0.000000  2.079442
# 41531  0.000000  0.000000  0.000000
# 13526  1.386294  1.098612  2.302585
# 29597  0.000000  0.000000  0.000000
# 388    0.000000  0.000000  0.000000
# 8212   0.000000  0.000000  0.000000
# 30570  0.000000  0.000000  0.000000
# 40209  0.000000  0.000000  0.000000
# 11752  0.000000  0.000000  0.000000
#
# [5000 rows x 3 columns]

# %%
plot_silhouette_scores(X2)

# %%
X2.replace([np.inf, -np.inf, 0], np.nan).dropna()
# Out:
#              q8        q9       q10
# 26643  2.484907  2.397895  2.708050
# 30240  2.397895  1.791759  2.397895
# 25781  1.609438  1.386294  2.890372
# 20344  4.219508  4.174387  4.564348
# 11483  3.178054  2.639057  3.688879
# 44525  1.609438  1.098612  2.995732
# 12653  0.693147  1.791759  2.197225
# 2607   1.386294  1.098612  1.791759
# 8258   2.079442  1.386294  2.944439
# 2062   1.386294  0.693147  2.397895
# 6989   0.693147  0.693147  2.079442
# 42834  1.098612  1.609438  1.791759
# 16245  1.098612  1.386294  2.079442
# 3627   1.945910  1.945910  2.639057
# 8302   0.693147  0.693147  1.945910
# 34937  0.693147  1.098612  1.386294
# 7282   3.135494  4.158883  3.135494
# 11884  0.693147  0.693147  1.386294
# 13477  1.386294  1.098612  2.397895
# 19906  1.098612  2.079442  2.079442
# 17317  2.397895  0.693147  3.091042
# 2498   0.693147  0.693147  1.945910
# 5940   4.454347  4.574711  4.634729
# 29288  1.791759  1.791759  3.713572
# 10847  0.693147  1.098612  0.693147
# 18421  2.772589  2.302585  2.944439
# 43857  1.791759  2.302585  1.791759
# 33173  0.693147  0.693147  0.693147
# 23470  2.302585  2.197225  1.386294
# 40936  1.945910  2.484907  2.484907
# ...         ...       ...       ...
# 37030  0.693147  1.386294  1.098612
# 2126   1.098612  0.693147  2.639057
# 29209  3.258097  3.912023  3.433987
# 18922  0.693147  1.098612  1.386294
# 28255  0.693147  0.693147  1.791759
# 33668  1.791759  1.386294  2.639057
# 39464  2.397895  1.945910  2.833213
# 15757  3.258097  2.302585  3.637586
# 43290  0.693147  1.098612  1.386294
# 8050   2.564949  1.791759  3.044522
# 2805   1.609438  1.609438  2.397895
# 8331   1.386294  0.693147  2.484907
# 25528  3.135494  2.302585  3.688879
# 29660  1.386294  1.098612  1.609438
# 28146  1.945910  0.693147  2.197225
# 24302  2.944439  3.555348  3.988984
# 10851  2.890372  2.944439  3.044522
# 16241  2.397895  2.079442  3.555348
# 27155  0.693147  1.098612  1.098612
# 40421  1.791759  1.098612  2.564949
# 15323  2.079442  3.218876  3.663562
# 2109   2.564949  1.945910  2.564949
# 40187  1.098612  1.386294  2.397895
# 31184  4.248495  3.332205  4.276666
# 31951  3.178054  2.772589  3.713572
# 30429  0.693147  0.693147  0.693147
# 35319  3.401197  3.737670  3.761200
# 5984   1.945910  2.302585  2.197225
# 35555  1.386294  1.609438  1.609438
# 13526  1.386294  1.098612  2.302585
#
# [682 rows x 3 columns]

# %%
plot_silhouette_scores(X2)

# %% [markdown]
# ### Q4. Clusters for features: q11,q12,13

# %%
X3 = rows[['q11','q12','q13']]

# %%
plot_silhouette_scores(X3)

# %% [markdown]
# ### Q5. Inspect best clustering generated in Q4

# %%
# Best value of k=8 above
k_means_8 = KMeans(n_clusters=8).fit(X3)
k8_labels = k_means_8.labels_

clusters = {}
for label in k8_labels:
    try:
        clusters[label] += 1
    except:
        clusters[label] = 1

print (clusters)
# Out:
# {0: 1230, 1: 1532, 2: 702, 3: 131, 4: 731, 5: 78, 6: 254, 7: 342}

# %%
k8_centroids = k_means_8.cluster_centers_
for i in range(8):        
    df = X3[k8_labels==i]
    # plot observations
    plt.plot(df['q12'],df['q13'],'o')
    # plot centroid
    lines = plt.plot(k8_centroids[i,0],k8_centroids[i,1],'kx')
    # make the centroid x's bigger
    plt.setp(lines,ms=15.0)
    plt.setp(lines,mew=2.0)

pylab.rcParams['figure.figsize'] = (40, 24) 
plt.show()

# %%
for centroid in k8_centroids:
    print(centroid)
# Out:
# [  0.26382444   0.29860936  99.4375662 ]
# [ -4.90274488e-13   2.71782596e-13  -8.52651283e-14]
# [ 31.28454214  28.34703459  40.36842328]
# [  2.21101418  96.78934933   0.9996365 ]
# [ 22.08790254   9.95756316  67.95453431]
# [ 98.18376068   0.85470085   0.96153846]
# [  4.35620837  44.89060494  50.75318668]
# [ 48.49941249   2.12197546  49.37861205]

# %% [markdown]
# ##### The centroid of cluster that has almost equal weight of all 3 features is that of label 4 [ 31.35174902  28.53157027  40.11668071].

# %%
print (clusters[4])
# Out:
# 731

# %% [markdown]
# ### Q6. Clustering with k=5, q8-13,q15 & q17

# %%
X4 = rows[['q8','q9','q10','q11','q12','q13','q15','q17']]
# remove rows with inf
X4.replace([np.inf, -np.inf], np.nan).dropna
# Out:
# <bound method DataFrame.dropna of              q8        q9       q10        q11         q12         q13  q15  \
# 27737  0.000000  0.000000  0.000000   0.000000    0.000000    0.000000    7
# 27507  0.000000  0.000000  0.000000  50.000000    0.000000   50.000000    2
# 40526  0.000000  0.000000  0.000000   0.000000    0.000000  100.000000    7
# 18675  0.693147  0.000000  2.197225  18.181818    0.000000   81.818182    7
# 26643  2.484907  2.397895  2.708050  31.578947   28.947368   39.473684    7
# 4703   0.000000  0.000000  0.000000   0.000000    0.000000  100.000000    7
# 40409  0.000000  0.000000  0.000000   0.000000  100.000000    0.000000    4
# 6904   0.000000  0.000000  0.000000   0.000000    0.000000    0.000000    7
# 5343   0.000000  0.000000  0.000000   0.000000    0.000000    0.000000    7
# 16483  0.693147  0.000000  1.386294  33.333333    0.000000   66.666667    6
# 8491   0.693147  0.000000  0.000000  66.666667    0.000000   33.333333    6
# 12469  0.000000  0.000000  0.693147   0.000000    0.000000  100.000000    6
# 12925  0.000000  0.000000  1.098612   0.000000    0.000000  100.000000    7
# 2171   0.000000  0.000000  0.000000   0.000000   50.000000   50.000000    7
# 30240  2.397895  1.791759  2.397895  39.285714   21.428571   39.285714    4
# 17622  0.000000  0.000000  0.000000   0.000000    0.000000    0.000000    7
# 41886  0.000000  0.000000  0.000000   0.000000    0.000000  100.000000    5
# 1177   0.000000  0.000000  0.000000   0.000000    0.000000    0.000000    4
# 11193  0.000000  0.000000  0.000000   0.000000    0.000000  100.000000    6
# 22348  0.000000  0.000000  0.693147   0.000000   33.333333   66.666667    7
# 1074   0.000000  0.000000  0.000000   0.000000    0.000000    0.000000    5
# 23649  0.000000  0.000000  0.000000  33.333333   33.333333   33.333333    6
# 1074    944.000000
# 23649   122.875000
# 37134  1179.500000
# 25781  1299.333333
# 9030    246.500000
# 32108   846.000000
# 44230    26.000000
# 29135   230.000000
# 37750   392.333333
# 12000   325.000000
# ...            ...
# 11059  1051.000000
# 33684   230.500000
# 35319  1380.450000
# 8857    302.000000
# 25804   524.000000
# 5984   1579.000000
# 13000   589.727273
# 31512   264.000000
# 10552   681.250000
# 31205  1188.000000
# 33348  1332.000000
# 15430  1184.714286
# 27825   234.500000
# 16280   536.000000
# 10142   164.000000
# 1201    960.000000
# 35555   440.250000
# 25108    85.000000
# 43176    49.000000
# 13089   184.000000
# 22989   648.500000
# 31453   862.833333
# 41531  2225.000000
# 13526   856.600000
# 29597   237.000000
# 388    1244.000000
# 8212    100.500000
# 30570  1197.000000
# 40209   609.000000
# 11752   878.000000
#
# [5000 rows x 8 columns]>

# %% [markdown]
# ##### Calculate silhouette rating

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(X4)
    
labels = kmeans.labels_
k5_centroids = kmeans.cluster_centers_
    
s = silhouette_score(X4,labels,metric='euclidean')
print (s)
# Out:
# 0.530854984618

# %%
#from statistics import mean

ratings = {}
for i in range(5):
    cluster_indices = X4[k8_labels==i].index.values
    avg_star_ratings = mean([rows.ix[index]['q14'] for index in cluster_indices])
    ratings[i] = avg_star_ratings

print (ratings)

# %% [markdown]
# ### Q7

# %%
# create dataset
# import data
yelp_reviews = pd.read_csv('yelp_reviewers.txt',sep='|',header=0)
cols = ['q8','q9','q10','q11','q12','q13','q15','q17','q18-1','q18-2','q18-3','q18-4','q18-5','q18-6','q18-7','q18-8','q18-9','q18-10a','q18-10b','q18-10c','q18-10d','q18-10e','q18-10f','q18-10g','q18-10h']
# sample data
# rows = yelp_reviews.sample(10000)
rows = rows[cols]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-9d5152c9fe09> in <module>()
#       5 # sample data
#       6 # rows = yelp_reviews.sample(10000)
# ----> 7 rows = rows[cols]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1961         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1962             # either boolean or fancy integer index
# -> 1963             return self._getitem_array(key)
#    1964         elif isinstance(key, DataFrame):
#    1965             return self._getitem_frame(key)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2005             return self.take(indexer, axis=0, convert=False)
#    2006         else:
# -> 2007             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2008             return self.take(indexer, axis=1, convert=True)
#    2009
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1148                 mask = check == -1
#    1149                 if mask.any():
# -> 1150                     raise KeyError('%s not in index' % objarr[mask])
#    1151
#    1152                 return _values_from_object(indexer)
#
# KeyError: "['q18-10a' 'q18-10b' 'q18-10c' 'q18-10d' 'q18-10e' 'q18-10f' 'q18-10g'\n 'q18-10h'] not in index"

# %%
# drop columns with high inf/-inf/nan values
for column in cols:
    df = rows[column]
    if (sum([0 if np.isnan(row) else 1 for row in df])) in range(0,100):
#         print(column)
        cols.remove(column)

X5 = rows[cols]

# %% [markdown]
# #### Calculate silhouette metric

# %%
# replace all inf and NaN by 0
# wouldn't replacing inf values in log columns modify the data?
X5 = X5.replace([np.inf, -np.inf], np.nan).dropna(subset=['q8','q9','q10'])
X5 = X5.replace([np.nan,np.inf,-np.inf], 0)

# %%
plot_silhouette_scores(X5)
